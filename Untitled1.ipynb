# %%
from attack_script import *

# %%
custom_model = buildUploadedModel('resnet18', "../pretrained_resnet18.pt")

# %%
cfg = breaching.get_config()
# Out:
# Investigating use case single_imagenet with server type honest_but_curious.

# %%
setup, user, server, attacker, model, loss_fn = setup_attack(cfg, torch_model=custom_model)
# Out:
# {'device': device(type='cpu'), 'dtype': torch.float32}

# %%
cfg.attack.optim.max_iterations = 100
cfg.attack.optim.callback = 1

# %%
reconstructed_user_data, true_user_data, server_payload = perform_attack(cfg, setup, user, server, attacker, model, loss_fn)
# Out:
# Model architecture ResNet18 loaded with 11,380,173 parameters and 9,620 buffers.
# Overall this is a data ratio of      76:1 for target shape [1, 3, 224, 224] given that num_queries=1.
# User (of type UserSingleStep) with settings:
#     Number of data points: 1
#
#     Threat model:
#     User provides labels: False
#     User provides buffers: False
#     User provides number of data points: True
#
#     Data:
#     Dataset: ImageNetAnimals
#     user: 0
#
#
# Server (of type HonestServer) with settings:
#     Threat model: Honest-but-curious
#     Number of planned queries: 1
#     Has external/public data: False
#
#     Model:
#         model specification: ResNet18
#         model state: default
#         public buffers: True
#
#     Secrets: {}
#
# Attacker (of type OptimizationBasedAttacker) with settings:
#     Hyperparameter Template: invertinggradients
#
#     Objective: Cosine Similarity with scale=1.0 and task reg=0.0
#     Regularizers: Total Variation, scale=0.2. p=1 q=1.
#     Augmentations:
#
#     Optimization Setup:
#         optimizer: adam
#         signed: hard
#         step_size: 0.1
#         boxed: True
#         max_iterations: 100
#         step_size_decay: step-lr
#         langevin_noise: 0.0
#         warmup: 0
#         grad_clip: None
#         callback: 1
#
# reconstructing attack

# %%
metrics = get_metrics(reconstructed_user_data, true_user_data, server_payload, server, cfg, setup)
metrics
# Out:
# {'mse': 0.016683289781212807,
#  'psnr': 17.777183532714844,
#  'rpsnr': 17.81234359741211,
#  'ssim': 0.2853616774082184,
#  'max_ssim': 0.2853616774082184,
#  'max_rpsnr': 17.81234359741211,
#  'order': tensor([0]),
#  'IIP-pixel': 1.0,
#  'lpips': 0.8941851258277893,
#  'feat_mse': 0.010704788379371166,
#  'parameters': 11380173,
#  'label_acc': 1.0}

# %%
cfg.case.data
# Out:
# {'db': {'name': None}, 'name': 'ImageNetAnimals', 'modality': 'vision', 'task': 'classification', 'path': '/Users/sumithsalluri/data/imagenet', 'size': 1281167, 'classes': 397, 'shape': [3, 224, 224], 'normalize': True, 'mean': [0.485, 0.456, 0.406], 'std': [0.229, 0.224, 0.225], 'augmentations_train': {'RandomResizedCrop': 224, 'RandomHorizontalFlip': 0.5}, 'augmentations_val': {'Resize': 256, 'CenterCrop': 224}, 'default_clients': 50, 'partition': 'balanced', 'examples_from_split': 'validation', 'batch_size': 128, 'caching': False}
